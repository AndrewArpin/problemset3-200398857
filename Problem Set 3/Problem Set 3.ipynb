# %% [markdown]
# # Andrew Arpin 200398857 - Problem Set 2

# %% [markdown]
# # Question 1
#
# <center><img src="q1.png"></center>

# %%
#step 1
#step 2
#step 3
import numpy as np
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|')
#step 4
data.groupby('occupation')['age'].mean()
#step 5
data['male'] = data['gender'].apply(lambda x: 1 if x == 'M' else 0)
totals = data.groupby('occupation')['male'].sum() 
(totals / data.groupby('occupation')['gender'].count())
#step 6
data.groupby('occupation')['age'].max()
data.groupby('occupation')['age'].min()
#step 7
data.groupby(['occupation', 'gender'])['age'].mean()
#step 8
data['male'] = data['gender'].apply(lambda x: 1 if x == 'M' else 0)
data['female'] = data['gender'].apply(lambda x: 1 if x == 'F' else 0)

totalM = data.groupby('occupation')['male'].sum() 
totalF = data.groupby('occupation')['female'].sum() 
M = (totalM / data.groupby('occupation')['gender'].count())
F = (totalF / data.groupby('occupation')['gender'].count())
print('total males', M)
print('total females', F)
# Out:
# total males occupation
# administrator    0.544304
# artist           0.535714
# doctor           1.000000
# educator         0.726316
# engineer         0.970149
# entertainment    0.888889
# executive        0.906250
# healthcare       0.312500
# homemaker        0.142857
# lawyer           0.833333
# librarian        0.431373
# marketing        0.615385
# none             0.555556
# other            0.657143
# programmer       0.909091
# retired          0.928571
# salesman         0.750000
# scientist        0.903226
# student          0.693878
# technician       0.962963
# writer           0.577778
# dtype: float64
# total females occupation
# administrator    0.455696
# artist           0.464286
# doctor           0.000000
# educator         0.273684
# engineer         0.029851
# entertainment    0.111111
# executive        0.093750
# healthcare       0.687500
# homemaker        0.857143
# lawyer           0.166667
# librarian        0.568627
# marketing        0.384615
# ...

# %% [markdown]
# # Question 2
# <center><img src="q2.png"></center>
# <center><img src="q2b.png"></center>

# %%
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
import numpy as np
import pandas as pd
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

#Step 4. Select only the Goal column
goals = euro12["Goals"]
print(goals)

#Step 5. How many team participated in the Euro2012?
Teams = len(euro12.index)
print("There are " + str(Teams) + " Teams")

#Step 6. What is the number of columns in the dataset?
Columns = len(euro12.columns)
print("There are " + str(Columns) +" columns")

#Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
#Step 8. Sort the teams by Red Cards, then to Yellow Cards
discipline = euro12.sort_values(["Red Cards","Yellow Cards"], ascending = (False,False))
print(discipline)

#Step 9. Calculate the mean Yellow Cards given per Team
yellow = euro12[["Yellow Cards"]]
print(yellow.mean())

#Step 10. Filter teams that scored more than 6 goalsStep 11. Select the teams that start with G
abc = euro12[(euro12["Goals"]>6) & (euro12["Team"].str.startswith("G"))]
print(abc)
           
#Step 12. Select the first 7 columns
firstcolumns = euro12.iloc[:, :7]
print(firstcolumns)

#Step 13. Select all columns except the last 3
lastcolumn = euro12.iloc[:, -3:]
print(lastcolumn) 

# #Step 14. Present only the Shooting Accuracy from England, Italy and Russia
shootingacc = euro12[(euro12["Team"]=="England") | (euro12["Team"]=="Italy")| (euro12["Team"]=="Russia")] 
shootingacc = shootingacc["Shooting Accuracy"]
print(shootingacc)
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64
# There are 16 Teams
# There are 35 columns
#                    Team  Goals  Shots on target  Shots off target  \
# 6                Greece      5                8                18
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 13                Spain     12               42                33
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 4                France      3               22                24
# ...

# %% [markdown]
# # Question 3
# <center><img src="q3.png"></center>

# %%
#step 1
import numpy as np
import pandas as pd

#series 1 
series1 = np.random.randint(1,4,100)
series1 = pd.Series(series1)
#series 2
series2 = np.random.randint(1,3,100)
series2 = pd.Series(series2)
#series 3
series3 = np.random.randint(10000,30000,100)
series3 = pd.Series(series3)
#step 3
Housing = pd.DataFrame({'ser1':series1, 'ser2':series2, 'ser3':series3})
Housing
#step 4
Housing.rename(columns={'ser1':'bedrs', 'ser2':'bathrs', 'ser3':'price_sqr_meter'})
#step 5
bigcolumn = pd.concat([series1,series2,series3])
bigcolumn 
#Step 6
#The index when displaying bigcolumn is only 99 as seen is step 5
#Step 7
bigcolumn = bigcolumn.reset_index(drop=True)
bigcolumn
# Out:
# 0          1
# 1          1
# 2          2
# 3          2
# 4          3
#        ...
# 295    12578
# 296    13436
# 297    22310
# 298    15649
# 299    24058
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4
# <center><img src="q4.png"></center>
# <center><img src="q4b.png"></center>

# %%
#step 1,2
import numpy as np
import pandas as pd
data = pd.read_csv('wind.csv')
#step 3

#step 4
data['Yr'] = data['Yr'].apply(lambda x: "{}{}".format('19', x))
data
# Out:
#         Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...    ...  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# # Question 5
# <center><img src="q5.png"></center>

# %%
#step 1
#step 2
#step 3
import numpy as np
import pandas as pd
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
chipo
#step 4
print(chipo.head(10))
#step 5
print('there are', len(chipo), 'obesrvations')
#step 6
print('there are', len(chipo.columns) ,'columns')
#step 7 
print(chipo.columns.values)
#step 8 
print(chipo.index)
#step 9
print('the most ordered item is the',chipo.groupby('item_name').count()['quantity'].idxmax())
#step 10
chipo2 = chipo['item_name'].apply(lambda x: 1 if x == 'Chicken Bowl' else 0)
print(chipo2.sum())
#step 11
print(chipo.groupby('order_id').count()['quantity'].sum())
#step 12
print(chipo.groupby('choice_description').count()['quantity'].idxmax())
#step 13
chipoP = chipo['item_price'].str.replace(r'\$', '').astype(float)
print('formatted', chipoP)
print(chipoP.dtypes)
#step 14
print('cost', chipoP.sum())
#step 15 does this mean just count of uniqe orders the question phrasing is weird
print("num of orders",chipo['order_id'].nunique())
#step 16 not right but... 
print("price per item",chipoP.mean())
#step 17 
print("unique items orders", chipo['item_name'].nunique())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# # Question 6
# <center><img src="q6.png"></center>

# %%
import numpy as np
import pandas as pd
data = pd.read_csv("us-marriages-divorces-1867-2014.csv")
print(data)

ax = plt.gca()

data.plot(kind='line', x='Year', y='Divorces_per_1000', color='blue', ax=ax, label='Divorces_per_1000')
data.plot(kind='line', x='Year', y='Marriages_per_1000', color='red', ax=ax, label='Marriages_per_1000')
plt.ylabel('Divores and Marriages per 1000')
plt.show()
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %% [markdown]
# # Question 7
#
# <center><img src="q7.png"></center>

# %%
df = pd.read_csv("us-marriages-divorces-1867-2014.csv")
print(df)
filter = df['Year']==2011
df.where(filter, inplace = True)
print(df)
data.plot(kind='line', x='Year', y='Divorces_per_1000', color='blue', ax=ax, label='Divorces_per_1000')
data.plot(kind='line', x='Year', y='Marriages_per_1000', color='red', ax=ax, label='Marriages_per_1000')
plt.ylabel('Divores and Marriages per 1000')
plt.show()
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %% [markdown]
# # Question 8
#
# <center><img src="q8.png"></center>

# %%
data = pd.read_csv("actor_kill_counts.csv")
new = data.sort_values(by='Count',ascending=False )
print(new)
new.plot.barh(x ='Actor', y='Count', )
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 7     Sylvester Stallone    267
# 4         Dolph Lundgren    239
# 8    Tomisaburo Wakayama    226
# 2         Clint Eastwood    207
# 6           Nicolas Cage    204
# 5                 Jet Li    201
# 3             Clive Owen    194
# 9          Wesley Snipes    193
# <AxesSubplot:ylabel='Actor'>

# %% [markdown]
# # Question 9
# <center><img src="q9.png"></center>

# %%
import matplotlib.pyplot as plt
data = pd.read_csv("roman-emperor-reigns.csv")
l = data['Cause_of_Death'].unique()
print(l)
a = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Possibly assassinated' else 0)
b = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Illness' else 0)
c = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Assassinated' else 0)
d = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Killed in battle' else 0)
e = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Executed' else 0)
f = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Natural causes' else 0)
g = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Died in captivity' else 0)
h = data['Cause_of_Death'].apply(lambda x: 1 if x == 'Suicide' else 0)

data =[a.sum(),b.sum(),c.sum(),d.sum(),e.sum(),f.sum(),g.sum(),h.sum()]
lables2 = 'Possibly assassinated','Illness','Assassinated','Killed in battle','Executed','Natural causes','Died in captivity','Suicide'
plt.pie(data, labels=lables2,autopct='%1.1f%%')
plt.title('My Title')
plt.axis('equal')
plt.show()
# Out:
# ['Possibly assassinated' 'Assassinated' 'Suicide' 'Natural causes'
#  'Illness' 'Executed' 'Killed in battle' 'Died in captivity']

# %% [markdown]
# # Question 10
# <center><img src="q10.png"></center>

# %%
data = pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")
print(data)
data.plot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', kind = 'scatter')
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611
# ...
